# %%
import math
import random
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
import warnings
import gerrychain   
from gerrychain import Graph, Partition, proposals, updaters, constraints, accept, MarkovChain
from gerrychain.updaters import cut_edges, Tally
from gerrychain.tree import recursive_tree_part
from gerrychain.proposals import recom
from gerrychain.accept import always_accept
from functools import partial

# %run data_cleaning.ipynb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12496\4217041957.py in <module>
#       7 import networkx as nx
#       8 import warnings
# ----> 9 import gerrychain
#      10 from gerrychain import Graph, Partition, proposals, updaters, constraints, accept, MarkovChain
#      11 from gerrychain.updaters import cut_edges, Tally
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\__init__.py in <module>
#       3
#       4 from ._version import get_versions
# ----> 5 from .chain import MarkovChain
#       6 from .graph import Graph
#       7 from .partition import GeographicPartition, Partition
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\chain.py in <module>
#      25 """
#      26
# ---> 27 from .constraints import Validator
#      28 from typing import Union, Iterable, Callable, Optional
#      29
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\constraints\__init__.py in <module>
#      37 """
#      38
# ---> 39 from .bounds import (
#      40     LowerBound,
#      41     SelfConfiguringLowerBound,
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\constraints\bounds.py in <module>
#       1 from typing import Callable, Tuple
# ----> 2 from ..partition import Partition
#       3
#       4
#       5 class Bounds:
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\partition\__init__.py in <module>
# ----> 1 from .partition import Partition
#       2 from .geographic import GeographicPartition
#       3
#       4 __all__ = ["Partition", "GeographicPartition"]
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\partition\partition.py in <module>
#       2 import networkx
#       3
# ----> 4 from gerrychain.graph.graph import FrozenGraph, Graph
#       5 from ..updaters import compute_edge_flows, flows_from_changes, cut_edges
#       6 from .assignment import get_assignment
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\graph\__init__.py in <module>
#      17 from .adjacency import *
#      18 from .geo import *
# ---> 19 from .graph import *
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\graph\graph.py in <module>
#     488
#     489
# --> 490 class FrozenGraph:
#     491     """
#     492     Represents an immutable graph to be partitioned. It is based off :class:`Graph`.
#
# ~\miniconda3\envs\cse217a\lib\site-packages\gerrychain\graph\graph.py in FrozenGraph()
#     543         return tuple(self.graph.neighbors(n))
#     544
# --> 545     @functools.cached_property
#     546     def node_indices(self) -> Iterable[Any]:
#     547         return self.graph.node_indices
#
# AttributeError: module 'functools' has no attribute 'cached_property'

# %%
# julia import data
centroid_locations = pd.read_csv(r"C:\Users\dodie\Downloads\spring 2024\trio-capstone\data\CensusTractCentroids.csv")
metro_locations = pd.read_csv(r"C:\Users\dodie\Downloads\spring 2024\trio-capstone\data\MetroLinkStations_REGISTERED.csv")
north_south_locations = pd.read_csv(r"C:\Users\dodie\Downloads\spring 2024\trio-capstone\data\MetroLinkStations_NS.csv")
census_data = data = pd.read_csv(r"C:\Users\dodie\Downloads\spring 2024\trio-capstone\data\B08119_stl_city.csv")
race_data = pd.read_csv(r"C:\Users\dodie\Downloads\spring 2024\trio-capstone\data\B08105_stl_city.csv")
stl = nx.read_weighted_edgelist(r"C:\Users\dodie\Downloads\spring 2024\trio-capstone\data pulling code\weighted_dual_list",delimiter='%',nodetype=str)

# %%
# get final data
by_tract = clean(census_data, race_data)
centroid_locations_small = centroid_locations[['NAMELSAD','INTPTLAT','INTPTLON']]
centroid_locations_small = centroid_locations_small.rename(columns = {"NAMELSAD": "location", "INTPTLAT" : "LAT", "INTPTLON" : "LON"})
full_data = by_tract.merge(centroid_locations_small, on='location')
full_data.head()
# Out:
#             location  estimate  transit weight  transit weight (pop)  \
# 0  Census Tract 1011      1039        0.003275              0.434255
# 1  Census Tract 1012      1921        0.001162              0.091845
# 2  Census Tract 1013      2161        0.003697              0.259777
# 3  Census Tract 1014      1502        0.010036              1.014476
# 4  Census Tract 1015      1318        0.003381              0.389424
#
#    income weight  income weight (pop)  race weight  race weight (pop)  \
# 0       0.009653             1.280070     0.007499           0.994323
# 1       0.009570             0.756349     0.012480           0.986410
# 2       0.009560             0.671698     0.013909           0.977253
# 3       0.009614             0.971790     0.010099           1.020846
# 4       0.009645             1.111024     0.008554           0.985409
#
#          LAT        LON
# 0  38.554718 -90.273620
# 1  38.561824 -90.274863
# 2  38.566560 -90.264211
# 3  38.562243 -90.253522
# 4  38.548544 -90.264511
