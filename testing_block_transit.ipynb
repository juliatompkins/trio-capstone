# %%
import numpy as np
import pandas as pd

# %%
transit_data = pd.read_csv("/Users/dylanmack/Library/CloudStorage/OneDrive-WashingtonUniversityinSt.Louis/ESE 499/block_level_transite_mode.csv")
metro_data = pd.read_csv("/Users/dylanmack/Library/CloudStorage/OneDrive-WashingtonUniversityinSt.Louis/ESE 499/MetroLinkStations_REGISTERED.csv")
transit_data
# Out:
#       Unnamed: 0         GEOID  \
# 0              1  295101011001
# 1              2  295101011001
# 2              3  295101011001
# 3              4  295101011001
# 4              5  295101011001
# ...          ...           ...
# 6589        6590  295101278002
# 6590        6591  295101278002
# 6591        6592  295101278002
# 6592        6593  295101278002
# 6593        6594  295101278002
#
#                                                location        name  estimate  \
# 0     Block Group 1; Census Tract 1011; St. Louis ci...  B08301_001       719
# 1     Block Group 1; Census Tract 1011; St. Louis ci...  B08301_002       674
# 2     Block Group 1; Census Tract 1011; St. Louis ci...  B08301_003       630
# 3     Block Group 1; Census Tract 1011; St. Louis ci...  B08301_004        44
# 4     Block Group 1; Census Tract 1011; St. Louis ci...  B08301_005        44
# ...                                                 ...         ...       ...
# ...
