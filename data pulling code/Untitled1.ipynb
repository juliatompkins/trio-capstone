# %%
import networkx as nx
import matplotlib.pyplot as plt 

graph = nx.read_gpickle('weighted_dual.pkl')

# %%
nx.draw(graph, with_labels=False, node_color='skyblue', font_weight='bold', node_size=10)
plt.show()

# %%
n = nx.read_edgelist('weighted_dual_list')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\miniconda3\envs\gdal\lib\site-packages\networkx\readwrite\edgelist.py:274, in parse_edgelist(lines, comments, delimiter, create_using, nodetype, data)
#     273         edgedata_str = " ".join(d)
# --> 274     edgedata = dict(literal_eval(edgedata_str.strip()))
#     275 except Exception as err:
#
# File ~\miniconda3\envs\gdal\lib\ast.py:62, in literal_eval(node_or_string)
#      61 if isinstance(node_or_string, str):
# ---> 62     node_or_string = parse(node_or_string, mode='eval')
#      63 if isinstance(node_or_string, Expression):
#
# File ~\miniconda3\envs\gdal\lib\ast.py:50, in parse(source, filename, mode, type_comments, feature_version)
#      49 # Else it should be an int giving the minor version for 3.x.
# ---> 50 return compile(source, filename, mode, flags,
# ...
