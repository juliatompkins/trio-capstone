# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('B08119_stl_city.csv')
data.head()
# Out:
#          GEOID                                     location        name  \
# 0  29510101100  Census Tract 1011; St. Louis city; Missouri  B08119_001
# 1  29510101100  Census Tract 1011; St. Louis city; Missouri  B08119_002
# 2  29510101100  Census Tract 1011; St. Louis city; Missouri  B08119_003
# 3  29510101100  Census Tract 1011; St. Louis city; Missouri  B08119_004
# 4  29510101100  Census Tract 1011; St. Louis city; Missouri  B08119_005
#
#    estimate  moe                                   label  \
# 0      1145  200                        Estimate!!Total:
# 1       114   64  Estimate!!Total:!!$1 to $9,999 or loss
# 2        47   32    Estimate!!Total:!!$10,000 to $14,999
# 3        73   47    Estimate!!Total:!!$15,000 to $24,999
# 4       194  145    Estimate!!Total:!!$25,000 to $34,999
#
#                                              concept geography
# 0  MEANS OF TRANSPORTATION TO WORK BY WORKERS' EA...     tract
# 1  MEANS OF TRANSPORTATION TO WORK BY WORKERS' EA...     tract
# 2  MEANS OF TRANSPORTATION TO WORK BY WORKERS' EA...     tract
# 3  MEANS OF TRANSPORTATION TO WORK BY WORKERS' EA...     tract
# 4  MEANS OF TRANSPORTATION TO WORK BY WORKERS' EA...     tract

# %%
data = data[['location','label','estimate','moe']]
data['label'] = data['label'].str.replace('Estimate', '').str.replace('Total', '').str.replace('!!', '').str.replace(':', '')
data.head()
# Out:
#                                       location                 label  \
# 0  Census Tract 1011; St. Louis city; Missouri
# 1  Census Tract 1011; St. Louis city; Missouri  $1 to $9,999 or loss
# 2  Census Tract 1011; St. Louis city; Missouri    $10,000 to $14,999
# 3  Census Tract 1011; St. Louis city; Missouri    $15,000 to $24,999
# 4  Census Tract 1011; St. Louis city; Missouri    $25,000 to $34,999
#
#    estimate  moe
# 0      1145  200
# 1       114   64
# 2        47   32
# 3        73   47
# 4       194  145

# %%
all_totals = data[data['label']=='']
all_totals.head()
# Out:
#                                         location label  estimate  moe
# 0    Census Tract 1011; St. Louis city; Missouri            1145  200
# 63   Census Tract 1012; St. Louis city; Missouri            1921  283
# 126  Census Tract 1013; St. Louis city; Missouri            2161  386
# 189  Census Tract 1014; St. Louis city; Missouri            1502  394
# 252  Census Tract 1015; St. Louis city; Missouri            1318  333

# %%
trans_totals_mask = ~data['label'].astype(str).str.contains('[$]')
trans_totals = data.loc[trans_totals_mask][1:]
trans_totals
# Out:
#                                          location  \
# 9     Census Tract 1011; St. Louis city; Missouri
# 18    Census Tract 1011; St. Louis city; Missouri
# 27    Census Tract 1011; St. Louis city; Missouri
# 36    Census Tract 1011; St. Louis city; Missouri
# 45    Census Tract 1011; St. Louis city; Missouri
# ...                                           ...
# 6507  Census Tract 1278; St. Louis city; Missouri
# 6516  Census Tract 1278; St. Louis city; Missouri
# 6525  Census Tract 1278; St. Louis city; Missouri
# 6534  Census Tract 1278; St. Louis city; Missouri
# 6543  Census Tract 1278; St. Louis city; Missouri
#
#                                              label  estimate  moe
# 9                 Car, truck, or van - drove alone      1022  191
# 18                  Car, truck, or van - carpooled        78   52
# 27       Public transportation (excluding taxicab)        31   33
# 36                                          Walked         0   12
# 45    Taxicab, motorcycle, bicycle, or other means         7   20
# ...                                            ...       ...  ...
# 6507                Car, truck, or van - carpooled        11   16
# 6516     Public transportation (excluding taxicab)       161   90
# 6525                                        Walked       318  106
# 6534  Taxicab, motorcycle, bicycle, or other means        28   27
# 6543                              Worked from home        97   40
#
# [727 rows x 4 columns]

# %%
income_totals = data[data['label'].str.startswith("$")]
income_totals
# Out:
#                                          location                 label  \
# 1     Census Tract 1011; St. Louis city; Missouri  $1 to $9,999 or loss
# 2     Census Tract 1011; St. Louis city; Missouri    $10,000 to $14,999
# 3     Census Tract 1011; St. Louis city; Missouri    $15,000 to $24,999
# 4     Census Tract 1011; St. Louis city; Missouri    $25,000 to $34,999
# 5     Census Tract 1011; St. Louis city; Missouri    $35,000 to $49,999
# ...                                           ...                   ...
# 6493  Census Tract 1278; St. Louis city; Missouri    $25,000 to $34,999
# 6494  Census Tract 1278; St. Louis city; Missouri    $35,000 to $49,999
# 6495  Census Tract 1278; St. Louis city; Missouri    $50,000 to $64,999
# 6496  Census Tract 1278; St. Louis city; Missouri    $65,000 to $74,999
# 6497  Census Tract 1278; St. Louis city; Missouri       $75,000 or more
#
#       estimate  moe
# 1          114   64
# 2           47   32
# 3           73   47
# 4          194  145
# 5          303   87
# ...        ...  ...
# 6493       226  148
# 6494       165   74
# 6495        63   43
# 6496        59   81
# 6497        27   37
#
# [832 rows x 4 columns]

# %%
not_to_include = pd.concat([trans_totals, income_totals, all_totals])
merged_df = pd.merge(data, not_to_include, how='left', indicator=True)
no_totals = merged_df[merged_df['_merge'] == 'left_only'].drop(columns=['_merge'])[1:]

split_data = no_totals['label'].str.split('$', 1, expand=True)
no_totals[['transportation', 'income']] = split_data
no_totals.drop(columns=['label'], inplace=True)
no_totals['income'] = '$' + no_totals['income']

from_this = no_totals['income'].unique()
to_this = [1, 10000, 15000, 25000, 35000, 50000, 65000, 75000]
no_totals['avg income'] = no_totals['income'].replace(from_this, to_this)

print(no_totals.head())
# Out:
#                                        location  estimate  moe  \
# 11  Census Tract 1011; St. Louis city; Missouri        47   32
# 12  Census Tract 1011; St. Louis city; Missouri        66   47
# 13  Census Tract 1011; St. Louis city; Missouri       155  141
# 14  Census Tract 1011; St. Louis city; Missouri       259   92
# 15  Census Tract 1011; St. Louis city; Missouri       188   79
#
#                       transportation              income  avg income
# 11  Car, truck, or van - drove alone  $10,000 to $14,999           1
# 12  Car, truck, or van - drove alone  $15,000 to $24,999       10000
# 13  Car, truck, or van - drove alone  $25,000 to $34,999       15000
# 14  Car, truck, or van - drove alone  $35,000 to $49,999       25000
# 15  Car, truck, or van - drove alone  $50,000 to $64,999       35000

# %%
groupby_trans = no_totals.groupby('transportation')['estimate'].sum()
groupby_income = no_totals.groupby('income')['estimate'].sum()

plt.subplot(1,2,1)
plt.bar(groupby_trans.index, groupby_trans)
plt.xticks(rotation=45, ha="right")
plt.title('Transportation to Work in STL City')
plt.subplot(1,2,2)
plt.bar(groupby_income.index, groupby_income)
plt.xticks(rotation=45, ha="right")
plt.title('Income in STL City')
plt.subplots_adjust(left=0.1, right=1.2)
plt.show()
plt.savefig('total_trans_income.png')

# %%
groupby_both = no_totals.groupby(['income', 'transportation'])['estimate'].sum().unstack()
groupby_both.plot(kind='barh', stacked=True)
plt.title('Income by Transportation to Work in STL City')
# Out:
# Text(0.5, 1.0, 'Income by Transportation to Work in STL City')

# %%
trans_totals.rename(columns={'label': 'transportation'}, inplace=True)
trans_with_percentages = pd.merge(no_totals, trans_totals, on=['transportation', 'location'], suffixes=('_nototals', '_totals'))
trans_with_percentages['income percentage'] = trans_with_percentages['estimate_nototals'] / trans_with_percentages['estimate_totals']

wpg = trans_with_percentages.groupby(['transportation', 'income'])['income percentage'].mean().unstack()
wpg.plot(kind='bar', stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.xticks(rotation=45, ha="right")
plt.title('Transportation to Work by Income in STL City')
# Out:
# Text(0.5, 1.0, 'Transportation to Work by Income in STL City')

# %%
income_totals.rename(columns={'label': 'income'}, inplace=True)
inc_with_percentages = pd.merge(no_totals, income_totals, on=['income','location'], suffixes=('_nototals', '_totals'))
inc_with_percentages['transportation percentage'] = inc_with_percentages['estimate_nototals'] / inc_with_percentages['estimate_totals']

wpg = inc_with_percentages.groupby(['income', 'transportation'])['transportation percentage'].mean().unstack()
wpg.plot(kind='bar', stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.xticks(rotation=45, ha="right")
plt.title('Income by Transportation to Work in STL City')
plt.savefig('income_by_trans.png')
# Out:
# C:\Users\dodie\miniconda3\envs\cse217a\lib\site-packages\pandas\core\frame.py:4446: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
just_public = inc_with_percentages[inc_with_percentages['transportation']=='Public transportation (excluding taxicab)']

inc_pub = just_public.groupby(['income'])['estimate_nototals'].sum()
inc_pub.plot(kind='bar')
plt.xticks(rotation=45, ha="right")
plt.title('Percentage of public transportation users by income')
plt.savefig('trans_by_inc_percents.png')

# %%
tract_pub = just_public.groupby(['location'])['estimate_nototals'].sum()
tract_pub.plot(kind='hist')
plt.xticks(rotation=45, ha="right")
plt.title('Percentage of public transportation users by census tract')
plt.savefig('trans_by_tract.png')
